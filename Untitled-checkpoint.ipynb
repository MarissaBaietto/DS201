# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('real_estate_data_DS201.csv')

# %% [markdown]
# How are we going to "clean" this dataset?

# %%
df.head()
# Out:
#    id  bedrooms_total  baths_total  acres  sq_ft_tot_fn  tax_gross_amount  \
# 0   1               3            3   1.58          3740           11044.0
# 1   2               4            3   5.19          2276           13438.0
# 2   3               4            3   0.84          2200            6361.0
# 3   4               3            3  15.40          2926           11829.0
# 4   5               4            5   4.00          2817           10707.0
#
#    assessment_value_town  garage_capacity               address       city  \
# 0               538200.0              2.0  591 Church Hill Road  Woodstock
# 1               696500.0              2.0     354 Grove Hill Rd  Woodstock
# 2               329700.0              1.0            4 Prospect  Woodstock
# 3               697600.0              2.0        529 Stage Road    Pomfret
# 4               512100.0              2.0          283 Laughlin  Woodstock
#
# ...

# %% [markdown]
# Create a new column that shows how old the house is (assuming this data is from 2017)

# %%
df['house_age'] = 2017 - df['year_built']

# %%
df['house_age']
# Out:
# 0       47
# 1       27
# 2      217
# 3       22
# 4       49
#       ...
# 132     12
# 133     16
# 134    142
# 135    167
# 136     31
# Name: house_age, Length: 137, dtype: int64

# %% [markdown]
# Create a scatterplot comparing the house age and price.

# %%
sns.scatterplot(data=df, x=df['house_age'], y=df['price_closed'], hue=None, size=None, style=None, palette=None)
# Out:
# <Axes: xlabel='house_age', ylabel='price_closed'>

# %% [markdown]
# Create a histogram of prices to see distribution.

# %%
plt.hist(df['price_closed'], bins=20, log=False)
plt.ticklabel_format(style='plain')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Create a pairplot showing bathrooms, bedrooms, and price.

# %%
sns.pairplot(
    df,
    diag_kind="hist",
    x_vars=["bedrooms_total", "baths_total", "price_closed"],
    y_vars=["bedrooms_total", "baths_total", "price_closed"],
)
sns.set_theme(style='white')
